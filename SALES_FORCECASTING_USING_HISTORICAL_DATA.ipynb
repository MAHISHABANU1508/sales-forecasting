# %% [markdown]
# <a href="https://colab.research.google.com/github/MAHISHABANU1508/sales-forecasting/blob/main/SALES_FORCECASTING_USING_HISTORICAL_DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROJECT
# SALES FORCECASTING USING HISTORICAL DATA

# %%
pip install pandas numpy matplotlib statsmodels scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from  google.colab import files
uploaded=files.upload()


# Load data
data = pd.read_csv("csv.txt")

# Convert date column to datetime
data['date'] = pd.to_datetime(data['date'])
data.set_index('date', inplace=True)

# Plot original sales data
plt.figure()
plt.plot(data, label='Actual Sales')
plt.title("Historical Sales Data")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.show()

# Train ARIMA model (p,d,q)
model = ARIMA(data['sales'], order=(1,1,1))
model_fit = model.fit()

# Forecast next 6 months
forecast = model_fit.forecast(steps=6)

# Create forecast dates
forecast_dates = pd.date_range(
    start=data.index[-1],
    periods=7,
    freq='M'
)[1:]

# Plot forecast
plt.figure()
plt.plot(data, label='Actual Sales')
plt.plot(forecast_dates, forecast, label='Forecast', linestyle='--')
plt.title("Sales Forecast")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.legend()
plt.show()

# Print forecast values
print("Forecasted Sales:")
print(forecast)
# Out:
#      <input type="file" id="files-8b49fc46-272b-4ebc-8170-dad704592e8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b49fc46-272b-4ebc-8170-dad704592e8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
